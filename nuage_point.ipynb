# %%
#https://towardsdatascience.com/what-makes-a-song-likeable-dbfdb7abe404
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

fieldNumber = ['popularity', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'speechiness', 'valence']
data = pd.read_csv("./data/data.csv", usecols=fields)
data.popularity.describe()
dataSample = data.sample(50)

# %%
dataSample
# Out:
#                    genre                 artist_name  \
# 38156         Electronic                          Nu
# 112756               Pop                Hayden James
# 186942               Ska            Suburban Legends
# 64458               Folk                        RY X
# 93067              Indie                      Elohim
# 166447              Rock              Jackson Browne
# 189760               Ska                        NOFX
# 118987               Rap                XXXTENTACION
# 63726               Folk                     Alvvays
# 146105              Jazz               George Benson
# 128659         Classical           Jacques Offenbach
# 161671         Reggaeton                Kendo Kaponi
# 33746              Anime      School Food Punishment
# 30874              Anime             BUMP OF CHICKEN
# 72468   Children's Music  Jack's Big Music Show Cast
# 28167              Anime                       佐々木恵梨
# 172395            Comedy             Martin Lawrence
# ...

# %%
dataSample

# %%
sns.heatmap(dataSample, cmap = "coolwarm", cbar = False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [17], line 1
# ----> 1 sns.heatmap(dataSample, cmap = "coolwarm", cbar = False)
#
# File c:\Users\nad_m\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\matrix.py:543, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     540     ...     ax = sns.heatmap(corr, mask=mask, vmax=.3, square=True)
#     541 """
#     542 # Initialize the plotter object
# --> 543 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     544                       annot_kws, cbar, cbar_kws, xticklabels,
# ...

# %%
g = sns.regplot(data=dataSample, x="valence", y="popularity")
